# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium

from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter ('ignore' , category="ConvergenceWarning")

# %%
df_maps = pd.read_excel('testing.xlsx')
df_maps
# Out:
#      Place_Id                                  Place_Name  \
# 0          96                Alun Alun Selatan Yogyakarta
# 1         227                      Alun-Alun Kota Bandung
# 2         125          Alun-alun Utara Keraton Yogyakarta
# 3         274  Babakan Siliwangi City Forest Path Bandung
# 4         426                         Balai Kota Surabaya
# ..        ...                                         ...
# 432       361                Wisata Kampung Krisan Clapar
# 433       150                         Wisata Kraton Jogja
# 434       367                         Wisata Lereng Kelir
# 435       349                       Wisata Mangrove Tapak
# 436       262                                    Wot Batu
#
#                                            Description       Category  \
# 0    Alun-alun Selatan atau yang sekarang lebih dik...  Taman Hiburan
# 1    Alun-alun Bandung adalah pusat kota Bandung ya...  Taman Hiburan
# ...

# %% [markdown]
# MENAMPILKAN VISUALISASI MAP DENGAN FOLIUM

# %%
map = folium.Map(location=[df_maps.Lat.mean(), df_maps.Long.mean()], zoom_start=14, control_scale=True)
for index, location_info in df_maps.iterrows():
    folium.Marker([location_info["Lat"], location_info["Long"]], popup=location_info["City"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_maps[['Category']].nunique()
# Out:
# Category    6
# dtype: int64

# %%
df_maps[['Category']].value_counts()
# Out:
# Category
# Taman Hiburan         135
# Budaya                117
# Cagar Alam            106
# Bahari                 47
# Tempat Ibadah          17
# Pusat Perbelanjaan     15
# Name: count, dtype: int64

# %%
df_maps[['City']].value_counts()
# Out:
# City
# Yogyakarta    126
# Bandung       124
# Jakarta        84
# Semarang       57
# Surabaya       46
# Name: count, dtype: int64
