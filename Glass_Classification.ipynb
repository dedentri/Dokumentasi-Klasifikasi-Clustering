# %% [markdown]
# Attribute Information:
#
# Id number: 1 to 214
# RI: refractive index
# Na: Sodium (unit measurement: weight percent in corresponding oxide, as
# are attributes 4-10)
# Mg: Magnesium
# Al: Aluminum
# Si: Silicon
# K: Potassium
# Ca: Calcium
# Ba: Barium
# Fe: Iron
#
#
# Type of glass: (class attribute)
# -- 1 building_windows_float_processed
# -- 2 building_windows_non_float_processed
# -- 3 vehicle_windows_float_processed
# -- 4 vehicle_windows_non_float_processed (none in this database)
# -- 5 containers
# -- 6 tableware
# -- 7 headlamps

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
df = pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df = df.rename(columns={'RI': 'refractive index'})
df = df.rename(columns={'Na': 'Sodium'})
df = df.rename(columns={'Mg': 'Magnesium'})
df = df.rename(columns={'Al': 'Aluminum'})
df = df.rename(columns={'Si': 'Silicon'})
df = df.rename(columns={'K': 'Potassium'})
df = df.rename(columns={'Ca': 'Calcium'})
df = df.rename(columns={'Ba': 'Barium'})
df = df.rename(columns={'Fe': 'Iron'})
df
# Out:
#      refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0             1.52101   13.64       4.49      1.10    71.78       0.06
# 1             1.51761   13.89       3.60      1.36    72.73       0.48
# 2             1.51618   13.53       3.55      1.54    72.99       0.39
# 3             1.51766   13.21       3.69      1.29    72.61       0.57
# 4             1.51742   13.27       3.62      1.24    73.08       0.55
# ..                ...     ...        ...       ...      ...        ...
# 209           1.51623   14.14       0.00      2.88    72.61       0.08
# 210           1.51685   14.92       0.00      1.99    73.06       0.00
# 211           1.52065   14.36       0.00      2.02    73.42       0.00
# 212           1.51651   14.38       0.00      1.94    73.61       0.00
# 213           1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron  Type
# 0       8.75    0.00   0.0     1
# 1       7.83    0.00   0.0     1
# 2       7.78    0.00   0.0     1
# 3       8.22    0.00   0.0     1
# 4       8.07    0.00   0.0     1
# ..       ...     ...   ...   ...
# 209     9.18    1.06   0.0     7
# 210     8.40    1.59   0.0     7
# 211     8.44    1.64   0.0     7
# 212     8.48    1.57   0.0     7
# 213     8.62    1.67   0.0     7
#
# [214 rows x 10 columns]

# %%
df['Type'] = df['Type'].replace(1, 'building_windows_float_processed')
df['Type'] = df['Type'].replace(2, 'building_windows_non_float_processed')
df['Type'] = df['Type'].replace(3, 'vehicle_windows_float_processed')
df['Type'] = df['Type'].replace(4, 'vehicle_windows_non_float_processed')
df['Type'] = df['Type'].replace(5, 'containers')
df['Type'] = df['Type'].replace(6, 'tableware')
df['Type'] = df['Type'].replace(7, 'headlamps')
df
# Out:
#      refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0             1.52101   13.64       4.49      1.10    71.78       0.06
# 1             1.51761   13.89       3.60      1.36    72.73       0.48
# 2             1.51618   13.53       3.55      1.54    72.99       0.39
# 3             1.51766   13.21       3.69      1.29    72.61       0.57
# 4             1.51742   13.27       3.62      1.24    73.08       0.55
# ..                ...     ...        ...       ...      ...        ...
# 209           1.51623   14.14       0.00      2.88    72.61       0.08
# 210           1.51685   14.92       0.00      1.99    73.06       0.00
# 211           1.52065   14.36       0.00      2.02    73.42       0.00
# 212           1.51651   14.38       0.00      1.94    73.61       0.00
# 213           1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron                              Type
# 0       8.75    0.00   0.0  building_windows_float_processed
# 1       7.83    0.00   0.0  building_windows_float_processed
# 2       7.78    0.00   0.0  building_windows_float_processed
# 3       8.22    0.00   0.0  building_windows_float_processed
# 4       8.07    0.00   0.0  building_windows_float_processed
# ..       ...     ...   ...                               ...
# 209     9.18    1.06   0.0                         headlamps
# 210     8.40    1.59   0.0                         headlamps
# 211     8.44    1.64   0.0                         headlamps
# 212     8.48    1.57   0.0                         headlamps
# 213     8.62    1.67   0.0                         headlamps
#
# [214 rows x 10 columns]

# %%
sns.countplot( y = df['Type'])
print("Jumlah masing masing tipe: ")
df['Type'].value_counts()
# Out:
# Jumlah masing masing tipe:
# Type
# building_windows_non_float_processed    76
# building_windows_float_processed        70
# headlamps                               29
# vehicle_windows_float_processed         17
# containers                              13
# tableware                                9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   refractive index  214 non-null    float64
#  1   Sodium            214 non-null    float64
#  2   Magnesium         214 non-null    float64
#  3   Aluminum          214 non-null    float64
#  4   Silicon           214 non-null    float64
#  5   Potassium         214 non-null    float64
#  6   Calcium           214 non-null    float64
#  7   Barium            214 non-null    float64
#  8   Iron              214 non-null    float64
#  9   Type              214 non-null    object
# dtypes: float64(9), object(1)
# memory usage: 16.8+ KB

# %%
df.describe()
# Out:
#        refractive index      Sodium   Magnesium    Aluminum     Silicon  \
# count        214.000000  214.000000  214.000000  214.000000  214.000000
# mean           1.518365   13.407850    2.684533    1.444907   72.650935
# std            0.003037    0.816604    1.442408    0.499270    0.774546
# min            1.511150   10.730000    0.000000    0.290000   69.810000
# 25%            1.516522   12.907500    2.115000    1.190000   72.280000
# 50%            1.517680   13.300000    3.480000    1.360000   72.790000
# 75%            1.519157   13.825000    3.600000    1.630000   73.087500
# max            1.533930   17.380000    4.490000    3.500000   75.410000
#
#         Potassium     Calcium      Barium        Iron
# count  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009
# std      0.652192    1.423153    0.497219    0.097439
# min      0.000000    5.430000    0.000000    0.000000
# 25%      0.122500    8.240000    0.000000    0.000000
# 50%      0.555000    8.600000    0.000000    0.000000
# 75%      0.610000    9.172500    0.000000    0.100000
# max      6.210000   16.190000    3.150000    0.510000

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}") #melihat jumlah kolom dan baris
print(f"Duplicates: {df.duplicated().sum()}") #melihat data duplikat
print(f"missing data: {sum(df.isna().sum())}") #melihat data missing / lost
# Out:
# Rows: 214, Columns: 10
# Duplicates: 1
# missing data: 0

# %%
df.drop_duplicates(keep= 'first',inplace = True) #menghapus data duplikat

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}") #melihat jumlah kolom dan baris
print(f"Duplicates: {df.duplicated().sum()}") #melihat data duplikat
print(f"missing data: {sum(df.isna().sum())}") #melihat data missing / lost
# Out:
# Rows: 213, Columns: 10
# Duplicates: 0
# missing data: 0

# %%
df.plot(subplots=True, layout=(4,4), kind='box', figsize=(12,14))
# Out:
# refractive index       Axes(0.125,0.712609;0.168478x0.167391)
# Sodium              Axes(0.327174,0.712609;0.168478x0.167391)
# Magnesium           Axes(0.529348,0.712609;0.168478x0.167391)
# Aluminum            Axes(0.731522,0.712609;0.168478x0.167391)
# Silicon                Axes(0.125,0.511739;0.168478x0.167391)
# Potassium           Axes(0.327174,0.511739;0.168478x0.167391)
# Calcium             Axes(0.529348,0.511739;0.168478x0.167391)
# Barium              Axes(0.731522,0.511739;0.168478x0.167391)
# Iron                    Axes(0.125,0.31087;0.168478x0.167391)
# dtype: object

# %%
# def Handle_outlier(df, column_name):
#     # HITUNG Q1 DAN Q3
#     Q1 = np.percentile(df[column_name], 25)
#     Q3 = np.percentile(df[column_name], 75)

#     # HITUNG IQR
#     IQR = Q3 - Q1   

#     # Tentukan Batas Bawah Dan Batas Atas
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR

#     # IDENTIFIKASI OUTLIER DENGAN INTERQUARTIL
#     outliers = df[column_name][(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

#     if not outliers.empty:
#         print(f"Outliers berdasarkan IQR untuk kolom {column_name}:")
#         print(outliers)
#     else:
#         print(f"Tidak ditemukan outlier untuk kolom {column_name} berdasarkan metode interquartile.")

#     # GANTI NILAI OUTLIER
#     df[column_name] = np.where((df[column_name] < lower_bound), lower_bound, df[column_name])
#     df[column_name] = np.where((df[column_name] > upper_bound), upper_bound, df[column_name])

# %%
df
# Out:
#      refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0             1.52101   13.64       4.49      1.10    71.78       0.06
# 1             1.51761   13.89       3.60      1.36    72.73       0.48
# 2             1.51618   13.53       3.55      1.54    72.99       0.39
# 3             1.51766   13.21       3.69      1.29    72.61       0.57
# 4             1.51742   13.27       3.62      1.24    73.08       0.55
# ..                ...     ...        ...       ...      ...        ...
# 209           1.51623   14.14       0.00      2.88    72.61       0.08
# 210           1.51685   14.92       0.00      1.99    73.06       0.00
# 211           1.52065   14.36       0.00      2.02    73.42       0.00
# 212           1.51651   14.38       0.00      1.94    73.61       0.00
# 213           1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron                              Type
# 0       8.75    0.00   0.0  building_windows_float_processed
# 1       7.83    0.00   0.0  building_windows_float_processed
# 2       7.78    0.00   0.0  building_windows_float_processed
# 3       8.22    0.00   0.0  building_windows_float_processed
# 4       8.07    0.00   0.0  building_windows_float_processed
# ..       ...     ...   ...                               ...
# 209     9.18    1.06   0.0                         headlamps
# 210     8.40    1.59   0.0                         headlamps
# 211     8.44    1.64   0.0                         headlamps
# 212     8.48    1.57   0.0                         headlamps
# 213     8.62    1.67   0.0                         headlamps
#
# [213 rows x 10 columns]

# %%
# Handle_outlier(df, 'refractive index')
# Handle_outlier(df, 'Sodium')
# Handle_outlier(df, 'Magnesium')
# Handle_outlier(df, 'Aluminum')
# Handle_outlier(df, 'Silicon')
# Handle_outlier(df, 'Potassium')
# Handle_outlier(df, 'Calcium')
# Handle_outlier(df, 'Barium')
# Handle_outlier(df, 'Iron')

# %%
df.plot(subplots=True, layout=(4,4), kind='box', figsize=(12,14))
# Out:
# refractive index       Axes(0.125,0.712609;0.168478x0.167391)
# Sodium              Axes(0.327174,0.712609;0.168478x0.167391)
# Magnesium           Axes(0.529348,0.712609;0.168478x0.167391)
# Aluminum            Axes(0.731522,0.712609;0.168478x0.167391)
# Silicon                Axes(0.125,0.511739;0.168478x0.167391)
# Potassium           Axes(0.327174,0.511739;0.168478x0.167391)
# Calcium             Axes(0.529348,0.511739;0.168478x0.167391)
# Barium              Axes(0.731522,0.511739;0.168478x0.167391)
# Iron                    Axes(0.125,0.31087;0.168478x0.167391)
# dtype: object

# %%
df['Type'].value_counts()
# Out:
# Type
# building_windows_non_float_processed    76
# building_windows_float_processed        69
# headlamps                               29
# vehicle_windows_float_processed         17
# containers                              13
# tableware                                9
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
mapping1 = {
    'building_windows_float_processed': 1,
    'building_windows_non_float_processed': 2,
    'vehicle_windows_float_processed': 3,
    'vehicle_windows_non_float_processed': 4,
    'containers': 5,
    'tableware': 6,
    'headlamps': 7
}

# Menggunakan mapping untuk mengubah nilai-nilai pada kolom 'Type'
df['Type'] = df['Type'].map(mapping1)

df
# Out:
#      refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0             1.52101   13.64       4.49      1.10    71.78       0.06
# 1             1.51761   13.89       3.60      1.36    72.73       0.48
# 2             1.51618   13.53       3.55      1.54    72.99       0.39
# 3             1.51766   13.21       3.69      1.29    72.61       0.57
# 4             1.51742   13.27       3.62      1.24    73.08       0.55
# ..                ...     ...        ...       ...      ...        ...
# 209           1.51623   14.14       0.00      2.88    72.61       0.08
# 210           1.51685   14.92       0.00      1.99    73.06       0.00
# 211           1.52065   14.36       0.00      2.02    73.42       0.00
# 212           1.51651   14.38       0.00      1.94    73.61       0.00
# 213           1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron  Type
# 0       8.75    0.00   0.0     1
# 1       7.83    0.00   0.0     1
# 2       7.78    0.00   0.0     1
# 3       8.22    0.00   0.0     1
# 4       8.07    0.00   0.0     1
# ..       ...     ...   ...   ...
# 209     9.18    1.06   0.0     7
# 210     8.40    1.59   0.0     7
# 211     8.44    1.64   0.0     7
# 212     8.48    1.57   0.0     7
# 213     8.62    1.67   0.0     7
#
# [213 rows x 10 columns]

# %%
import matplotlib.pyplot as plt #korelasi hubungan antar variabel dapat dilihat dari korelasi di bawah
import seaborn as sns
plt.figure(figsize=(15,15))# bahwa Total_Phenols,Flavanoids, dan OD280 memliki pengaruh yang besar
sns.heatmap(df.corr(),annot=True,fmt=".2f",linewidths=0.7,cmap="coolwarm")
plt.show()

# %%
kolom=len(df.columns)
import scipy
from scipy import stats

z=[]
for i in range (0,kolom-1):
  k,y=stats.pearsonr(df.iloc[:,i],df.iloc[:,-1])
  z.append([i,df.columns[i], abs(k)])

z=sorted(z, key=lambda z:z[2], reverse=True)
z=pd.DataFrame(z,columns=["KolomKe","Nama Kolom","KoefisienKorelasi-Pearson"])
z
# Out:
#    KolomKe        Nama Kolom  KoefisienKorelasi-Pearson
# 0        2         Magnesium                   0.744195
# 1        3          Aluminum                   0.597432
# 2        7            Barium                   0.574896
# 3        1            Sodium                   0.508837
# 4        8              Iron                   0.191090
# 5        0  refractive index                   0.160140
# 6        4           Silicon                   0.147725
# 7        5         Potassium                   0.012455
# 8        6           Calcium                   0.002677

# %%
import matplotlib.pyplot as plt
g=z.head(5)
fig = plt.figure()

ax = fig.add_axes([1,1, 2, 2])
x_axis = g.iloc[:,1]
y_axis = g.iloc[:,2]

ax.bar(x_axis , y_axis, color = 'y', width = 0.5)

plt.title('Korelasi Feature (Dependent Variable) dengan Target - Koefisien Pearson')

plt.xlabel('Feature - Dependent variable (kolom)')
plt.ylabel('Koefisien Pearson')
plt.show()

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
from sklearn import tree
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=2)

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 25, random_state=2)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=2)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits=7, shuffle=True)

# %%
scores1 = cross_val_score(model, x, y, cv=kf)
print(scores1)
print('rata rata KFold nya adalah: ',scores1.mean())
# Out:
# [0.80645161 0.74193548 0.74193548 0.8        0.86666667 0.8
#  0.66666667]
# rata rata KFold nya adalah:  0.7748079877112135

# %%
prediksi_model = model.predict(x_test)
prediksi_model
# Out:
# array([2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 7, 2,
#        2, 2, 1, 2, 2, 6, 1, 7, 1, 1, 1, 2, 1, 1, 2, 2, 1, 2, 2, 2, 2],
#       dtype=int64)

# %%
from sklearn.metrics import accuracy_score
hasil1 = accuracy_score(prediksi_model,y_test)*100
print('Accuracy Score untuk algoritma Random Forest Adalah : ',accuracy_score(prediksi_model,y_test)*100,'%')
# Out:
# Accuracy Score untuk algoritma Random Forest Adalah :  69.76744186046511 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, prediksi_model)
classification_rep = classification_report(y_test, prediksi_model)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.6976744186046512
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.86      0.67      0.75        18
#            2       0.58      0.88      0.70        17
#            3       0.00      0.00      0.00         3
#            6       1.00      0.50      0.67         2
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.70        43
#    macro avg       0.69      0.54      0.58        43
# weighted avg       0.70      0.70      0.68        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# DECISION TREE

# %%
clf=tree.DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits=10, shuffle=True)

# %%
scores2 = cross_val_score(clf, x, y, cv=kf)
print(scores2)
print('rata rata KFold nya adalah: ',scores2.mean())
# Out:
# [0.59090909 0.68181818 0.68181818 0.85714286 0.9047619  0.47619048
#  0.66666667 0.61904762 0.57142857 0.66666667]
# rata rata KFold nya adalah:  0.6716450216450217

# %%
prediksi1 = clf.predict(x_test)
prediksi1
# Out:
# array([2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 7, 2,
#        2, 2, 1, 1, 2, 6, 1, 7, 1, 1, 3, 3, 1, 1, 2, 2, 1, 2, 5, 1, 2],
#       dtype=int64)

# %%
clf.fit(x_train, y_train)
#%%
predicted_value = clf.predict(x_test)
print(predicted_value)
#%%
tree.plot_tree(clf)
zeroes = 0
ones=0
# Out:
# [2 1 2 1 2 1 2 1 2 1 2 2 2 2 2 1 2 2 2 3 7 2 2 2 1 1 2 6 1 7 1 1 1 3 1 1 2
#  2 1 2 5 1 2]

# %%
from sklearn.metrics import accuracy_score
hasil2 = accuracy_score(prediksi1,y_test)*100
print('Accuracy Score untuk algoritma Decision Tree : ',accuracy_score(prediksi1,y_test)*100,'%')
# Out:
# Accuracy Score untuk algoritma Decision Tree :  65.11627906976744 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, prediksi1)
classification_rep = classification_report(y_test, prediksi1)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.6511627906976745
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.75      0.67      0.71        18
#            2       0.62      0.76      0.68        17
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         0
#            6       1.00      0.50      0.67         2
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.65        43
#    macro avg       0.56      0.43      0.48        43
# weighted avg       0.67      0.65      0.65        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
scores3 = cross_val_score(classifier, x, y, cv=kf)
print(scores3)
print('rata rata KFold nya adalah: ',scores3.mean())
# Out:
# [0.68181818 0.59090909 0.63636364 0.57142857 0.71428571 0.57142857
#  0.38095238 0.61904762 0.57142857 0.66666667]
# rata rata KFold nya adalah:  0.6004329004329004

# %%
y_predlog = classifier.predict(x_test)
y_predlog
# Out:
# array([2, 2, 2, 2, 2, 1, 2, 1, 2, 1, 6, 2, 2, 2, 2, 1, 1, 2, 1, 5, 7, 2,
#        2, 2, 1, 1, 1, 7, 1, 7, 1, 1, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1, 1],
#       dtype=int64)

# %%
accuracylog = accuracy_score(y_test, y_predlog)
hasil3 = accuracylog * 100
print('Akurasi menggunkan algoritma logistic Regression adalah :', (accuracylog)*100,'%')
# Out:
# Akurasi menggunkan algoritma logistic Regression adalah : 60.46511627906976 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_predlog)
classification_rep = classification_report(y_test, y_predlog)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.6046511627906976
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.67      0.67      0.67        18
#            2       0.55      0.65      0.59        17
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         0
#            6       1.00      0.50      0.67         2
#            7       0.67      0.67      0.67         3
#
#     accuracy                           0.60        43
#    macro avg       0.48      0.41      0.43        43
# weighted avg       0.59      0.60      0.59        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train, y_train)
y_prednaive = nb.predict(x_test)
y_prednaive
# Out:
# array([2, 1, 1, 3, 1, 1, 1, 1, 1, 1, 6, 2, 1, 1, 1, 3, 1, 1, 1, 5, 7, 1,
#        1, 3, 1, 1, 3, 6, 1, 7, 1, 1, 1, 1, 1, 3, 1, 3, 3, 1, 2, 1, 1],
#       dtype=int64)

# %%
scores4 = cross_val_score(nb, x, y, cv=kf)
print(scores4)
print('rata rata KFold nya adalah: ',scores4.mean())
# Out:
# [0.59090909 0.45454545 0.27272727 0.28571429 0.33333333 0.66666667
#  0.47619048 0.66666667 0.47619048 0.38095238]
# rata rata KFold nya adalah:  0.4603896103896103

# %%
accuracynavie = accuracy_score(y_test, y_prednaive)
hasil4 = accuracynavie * 100
print("Akurasi menggunakan algoritma naive bayes :", (accuracynavie)*100,'%')
# Out:
# Akurasi menggunakan algoritma naive bayes : 51.162790697674424 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_prednaive)
classification_rep = classification_report(y_test, y_prednaive)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.5116279069767442
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.50      0.78      0.61        18
#            2       1.00      0.18      0.30        17
#            3       0.14      0.33      0.20         3
#            5       0.00      0.00      0.00         0
#            6       1.00      1.00      1.00         2
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.51        43
#    macro avg       0.61      0.49      0.48        43
# weighted avg       0.73      0.51      0.49        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
y_predknn = knn.predict(x_test)
y_predknn
# Out:
# array([5, 3, 2, 3, 2, 1, 1, 1, 2, 1, 2, 6, 2, 1, 1, 1, 2, 2, 3, 5, 7, 3,
#        1, 1, 1, 2, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 2, 2, 1, 2, 6, 3, 2],
#       dtype=int64)

# %%
scores5 = cross_val_score(knn, x, y, cv=kf)
print(scores5)
print('rata rata KFold nya adalah: ',scores5.mean())
# Out:
# [0.63636364 0.59090909 0.81818182 0.76190476 0.85714286 0.57142857
#  0.61904762 0.66666667 0.52380952 0.80952381]
# rata rata KFold nya adalah:  0.6854978354978354

# %%
accuracyknn = accuracy_score(y_test, y_predknn)
hasil5 = accuracyknn * 100
print('akurasi untuk penggunaan algoritma KNN adalah :',(accuracyknn)*100,'%')
# Out:
# akurasi untuk penggunaan algoritma KNN adalah : 46.51162790697674 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_predknn)
classification_rep = classification_report(y_test, y_predknn)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.46511627906976744
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.56      0.56      0.56        18
#            2       0.53      0.47      0.50        17
#            3       0.20      0.33      0.25         3
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         2
#            7       1.00      0.33      0.50         3
#
#     accuracy                           0.47        43
#    macro avg       0.38      0.28      0.30        43
# weighted avg       0.53      0.47      0.48        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# LINEAR DESCRIMINANT ANALYSIS

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)
y_predLDA = lda.predict(x_test)
accuracyLDA = accuracy_score(y_test, y_predLDA)
y_predLDA
# Out:
# array([5, 1, 2, 2, 2, 1, 2, 1, 2, 1, 6, 2, 2, 2, 2, 2, 1, 2, 3, 5, 7, 2,
#        2, 2, 1, 2, 2, 6, 1, 7, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1],
#       dtype=int64)

# %%
scores6 = cross_val_score(lda, x, y, cv=kf)
print(scores6)
print('rata rata KFold nya adalah: ',scores6.mean())
# Out:
# [0.72727273 0.63636364 0.54545455 0.61904762 0.57142857 0.61904762
#  0.61904762 0.52380952 0.76190476 0.52380952]
# rata rata KFold nya adalah:  0.6147186147186147

# %%
hasil6 = accuracyLDA * 100
print("Akurasi untuk penggunaan algoritma Linear Discriminant Analysis:", (accuracyLDA)*100,'%')
# Out:
# Akurasi untuk penggunaan algoritma Linear Discriminant Analysis: 60.46511627906976 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_predLDA)
classification_rep = classification_report(y_test, y_predLDA)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.6046511627906976
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.75      0.50      0.60        18
#            2       0.54      0.76      0.63        17
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         0
#            6       1.00      1.00      1.00         2
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.60        43
#    macro avg       0.55      0.49      0.51        43
# weighted avg       0.64      0.60      0.60        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# EXTRA TRESS CLASIFIER

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators=100, random_state=0)
model.fit(x_train, y_train)
y_predETC = model.predict(x_test)
accuracyETC = accuracy_score(y_test, y_predETC)
y_predETC
# Out:
# array([2, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 3, 5, 7, 3,
#        3, 2, 1, 2, 2, 6, 1, 7, 1, 1, 1, 2, 1, 1, 2, 2, 1, 2, 5, 1, 2],
#       dtype=int64)

# %%
scores7 = cross_val_score(model, x, y, cv=kf)
print(scores7)
print('rata rata nya adalah: ',scores7.mean())
# Out:
# [0.77272727 0.72727273 0.81818182 0.80952381 0.71428571 0.80952381
#  0.61904762 0.80952381 0.80952381 0.76190476]
# rata rata nya adalah:  0.7651515151515151

# %%
hasil7 = accuracyETC * 100
print("Akurasi untuk penggunaan algoritma ExtraTreesClassifier :", (accuracyETC)*100,'%')
# Out:
# Akurasi untuk penggunaan algoritma ExtraTreesClassifier : 72.09302325581395 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_predETC)
classification_rep = classification_report(y_test, y_predETC)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.7209302325581395
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.81      0.72      0.76        18
#            2       0.68      0.76      0.72        17
#            3       0.67      0.67      0.67         3
#            5       0.00      0.00      0.00         0
#            6       1.00      0.50      0.67         2
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.72        43
#    macro avg       0.69      0.55      0.60        43
# weighted avg       0.77      0.72      0.74        43
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC
modelSVM = SVC(kernel = "linear")
modelSVM.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
scores9 = cross_val_score(modelSVM, x, y, cv=kf)
print(scores9)
print('rata rata SVM adalah: ',scores9.mean())
# Out:
# [0.77272727 0.59090909 0.5        0.61904762 0.57142857 0.76190476
#  0.57142857 0.52380952 0.61904762 0.66666667]
# rata rata SVM adalah:  0.6196969696969699

# %%
y_predSVM = modelSVM.predict(x_test)
y_predSVM
# Out:
# array([2, 2, 2, 2, 2, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 1, 1, 2, 1, 5, 7, 2,
#        2, 2, 1, 2, 1, 6, 1, 7, 1, 1, 2, 2, 1, 1, 2, 2, 1, 2, 2, 2, 1],
#       dtype=int64)

# %%
accuracySVM= accuracy_score(y_test, y_predSVM)
hasil9 = accuracySVM * 100
print("Akurasi untuk penggunaan algoritma SVM :", (accuracySVM)*100,'%')
# Out:
# Akurasi untuk penggunaan algoritma SVM : 58.139534883720934 %

# %% [markdown]
# HASIL KESELURUHAN DARI SEMUA SEVEN FOLD CROSS VALIDATON

# %%
print('rata rata random forest adalah: ',scores1.mean())
print('rata rata decision tree adalah: ',scores2.mean())
print('rata rata logistic regression adalah: ',scores3.mean())
print('rata rata naive bayes adalah: ',scores4.mean())
print('rata rata KNN adalah: ',scores5.mean())
print('rata rata Linear Discriminant Analysis adalah: ',scores6.mean())
print('rata rata ExtraTreesClassifier adalah: ',scores7.mean())
print('rata rata SVM adalah: ',scores9.mean())
print('=='*40)
print('rata rata tertinggi dari CROSS FOLD VALIDATON didapatkan oleh algoritma Random Forest: ',scores1.mean())
# Out:
# rata rata random forest adalah:  0.7748079877112135
# rata rata decision tree adalah:  0.6716450216450217
# rata rata logistic regression adalah:  0.6004329004329004
# rata rata naive bayes adalah:  0.4603896103896103
# rata rata KNN adalah:  0.6854978354978354
# rata rata Linear Discriminant Analysis adalah:  0.6147186147186147
# rata rata ExtraTreesClassifier adalah:  0.7651515151515151
# rata rata SVM adalah:  0.6196969696969699
# ================================================================================
# rata rata tertinggi dari CROSS FOLD VALIDATON didapatkan oleh algoritma Random Forest:  0.7748079877112135

# %% [markdown]
# HASIL KESELURUHAN DARI ALGORITMA YANG TELAH DICOBA

# %%
#kesimpulan dari beberapa algoritma pengukuran yang telah dilakukan
print('Accuracy Score untuk algoritma Random Forest Adalah : ',accuracy_score(prediksi_model,y_test)*100,'%')
print('Accuracy Score untuk algoritma Decision Tree : ',accuracy_score(prediksi1,y_test)*100,'%')
print('Akurasi menggunkan algoritma logistic Regression adalah :', (accuracylog)*100,'%')
print("Akurasi menggunakan algoritma naive bayes :", (accuracynavie)*100,'%')
print('akurasi untuk penggunaan algoritma KNN adalah :',(accuracyknn)*100,'%')
print("Akurasi untuk penggunaan algoritma Linear Discriminant Analysis:", (accuracyLDA)*100,'%')
print("Akurasi untuk penggunaan algoritma ExtraTreesClassifier :", (accuracyETC)*100,'%')
print("Akurasi untuk penggunaan algoritma SVM :", (accuracySVM)*100,'%')
print('=='*40)
print('JADI ALGORITMA YANG COCOK UNTUK KARAKTERISTIK DATASET INI ADALAH ALGORITMA DECISION TREE DENGAN AKURASI SEBESAR: ',accuracy_score(prediksi1,y_test)*100,'%')
# Out:
# Accuracy Score untuk algoritma Random Forest Adalah :  69.76744186046511 %
# Accuracy Score untuk algoritma Decision Tree :  65.11627906976744 %
# Akurasi menggunkan algoritma logistic Regression adalah : 60.46511627906976 %
# Akurasi menggunakan algoritma naive bayes : 51.162790697674424 %
# akurasi untuk penggunaan algoritma KNN adalah : 46.51162790697674 %
# Akurasi untuk penggunaan algoritma Linear Discriminant Analysis: 60.46511627906976 %
# Akurasi untuk penggunaan algoritma ExtraTreesClassifier : 72.09302325581395 %
# Akurasi untuk penggunaan algoritma SVM : 58.139534883720934 %
# ================================================================================
# JADI ALGORITMA YANG COCOK UNTUK KARAKTERISTIK DATASET INI ADALAH ALGORITMA DECISION TREE DENGAN AKURASI SEBESAR:  65.11627906976744 %

# %%
df_hasil_model = pd.DataFrame({"Model" : ["Random Forest", "Decision Tree", "logistic Regression", "naive bayes", "KNN", "Linear Discriminant Analysis","ExtraTreesClassifier","SVM"],
                         "Akurasi" : [hasil1, hasil2, hasil3, hasil4, hasil5, hasil6, hasil7, hasil9]})
df_hasil_model
# Out:
#                           Model    Akurasi
# 0                 Random Forest  69.767442
# 1                 Decision Tree  65.116279
# 2           logistic Regression  60.465116
# 3                   naive bayes  51.162791
# 4                           KNN  46.511628
# 5  Linear Discriminant Analysis  60.465116
# 6          ExtraTreesClassifier  72.093023
# 7                           SVM  58.139535

# %%
jawaban = pd.DataFrame({'Jawaban Asli':(y_test).reset_index(drop=True)})
jawaban
# Out:
#     Jawaban Asli
# 0              2
# 1              1
# 2              1
# 3              1
# 4              2
# 5              1
# 6              2
# 7              1
# 8              2
# 9              1
# 10             6
# 11             2
# 12             2
# 13             2
# 14             2
# 15             2
# 16             2
# 17             2
# 18             1
# 19             7
# 20             7
# 21             3
# 22             3
# 23             3
# 24             1
# 25             2
# 26             2
# 27             6
# 28             1
# 29             7
# 30             2
# 31             1
# 32             1
# 33             1
# 34             1
# 35             1
# 36             2
# 37             1
# 38             1
# 39             1
# 40             2
# 41             1
# 42             2

# %%
pred_ECT = pd.DataFrame({'Pred ETC':(y_predETC)})
pred_ECT
# Out:
#     Pred ETC
# 0          2
# 1          1
# 2          2
# 3          1
# 4          2
# 5          1
# 6          1
# 7          1
# 8          2
# 9          1
# 10         2
# 11         2
# 12         2
# 13         2
# 14         2
# 15         1
# 16         2
# 17         2
# 18         3
# 19         5
# 20         7
# 21         3
# 22         3
# 23         2
# 24         1
# 25         2
# 26         2
# 27         6
# 28         1
# 29         7
# 30         1
# 31         1
# 32         1
# 33         2
# 34         1
# 35         1
# 36         2
# 37         2
# 38         1
# 39         2
# 40         5
# 41         1
# 42         2
